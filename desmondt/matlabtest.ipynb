# %%
import numpy as np
import mne

# %%
raw = mne.io.read_raw_bdf(r"C:\Users\desmo\Documents\OpenBCI_GUI\Recordings\OpenBCI-BDF-2024-01-27_16-54-38.bdf", preload=True)
# Out:
# Extracting EDF parameters from C:\Users\desmo\Documents\OpenBCI_GUI\Recordings\OpenBCI-BDF-2024-01-27_16-54-38.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 3249  =      0.000 ...    25.992 secs...

# %%
raw.info
# Out:
# <Info | 8 non-empty values
#  bads: []
#  ch_names: EEG 1, EEG 2, EEG 3, EEG 4, EEG 5, EEG 6, EEG 7, EEG 8, EEG 9, ...
#  chs: 19 EEG
#  custom_ref_applied: False
#  highpass: 0.0 Hz
#  lowpass: 62.5 Hz
#  meas_date: 2024-01-27 16:54:39 UTC
#  nchan: 19
#  projs: []
#  sfreq: 125.0 Hz
#  subject_info: 3 items (dict)
# >

# %%
raw.plot()
# Out:
# <MNEBrowseFigure size 800x800 with 4 Axes>
# <MNEBrowseFigure size 800x800 with 4 Axes>

# %%
raw.pick("eeg")
# Out:
# <RawEDF | OpenBCI-BDF-2024-01-27_16-54-38.bdf, 19 x 3250 (26.0 s), ~502 kB, data loaded>

# %%
raw.info["bads"].extend(["Accel X", "Accel Y", "Accel Z"])

# %%
raw.plot()
# Out:
# <MNEBrowseFigure size 800x800 with 4 Axes>
# <MNEBrowseFigure size 800x800 with 4 Axes>

# %%
raw.info
# Out:
# <Info | 9 non-empty values
#  bads: 3 items (Accel X, Accel Y, Accel Z)
#  ch_names: EEG 1, EEG 2, EEG 3, EEG 4, EEG 5, EEG 6, EEG 7, EEG 8, EEG 9, ...
#  chs: 19 EEG
#  custom_ref_applied: False
#  highpass: 0.0 Hz
#  lowpass: 62.5 Hz
#  meas_date: 2024-01-27 16:54:39 UTC
#  nchan: 19
#  projs: []
#  sfreq: 125.0 Hz
#  subject_info: 3 items (dict)
# >

# %%
raw.info
# Out:
# <Info | 9 non-empty values
#  bads: 3 items (Accel X, Accel Y, Accel Z)
#  ch_names: EEG 1, EEG 2, EEG 3, EEG 4, EEG 5, EEG 6, EEG 7, EEG 8, EEG 9, ...
#  chs: 19 EEG
#  custom_ref_applied: False
#  highpass: 0.0 Hz
#  lowpass: 62.5 Hz
#  meas_date: 2024-01-27 16:54:39 UTC
#  nchan: 19
#  projs: []
#  sfreq: 125.0 Hz
#  subject_info: 3 items (dict)
# >

# %%
raw.plot();
# Out:
# <MNEBrowseFigure size 800x800 with 4 Axes>

# %%
highpass_fir = raw.copy().filter(l_freq=.1, h_freq=None)
# Out:
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 0.1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.10
# - Lower transition bandwidth: 0.10 Hz (-6 dB cutoff frequency: 0.05 Hz)
# - Filter length: 4125 samples (33.000 s)
# C:\Users\desmo\AppData\Local\Temp\ipykernel_16308\3403092799.py:1: RuntimeWarning: filter_length (4125) is longer than the signal (3250), distortion is likely. Reduce filter length or filter a longer signal.
#   highpass_fir = raw.copy().filter(l_freq=.1, h_freq=None)

# %%
highpass_fir.plot();
# Out:
# <MNEBrowseFigure size 800x800 with 4 Axes>

# %%
raw
# Out:
# <RawEDF | OpenBCI-BDF-2024-01-27_16-54-38.bdf, 19 x 3250 (26.0 s), ~502 kB, data loaded>

# %%
data, times = raw[:10]

# %%
data
# Out:
# array([[-4.61228219e-05, -4.77097957e-05, -4.64357463e-05, ...,
#         -3.80314909e-05, -4.82015340e-05, -3.81656014e-05],
#        [-1.57680372e-04, -1.57725075e-04, -1.56540433e-04, ...,
#         -3.27084233e-04, -3.29498221e-04, -3.25340797e-04],
#        [-6.19031526e-05, -6.21266700e-05, -6.20819665e-05, ...,
#         -6.21266700e-05, -6.85416203e-05, -6.21490218e-05],
#        ...,
#        [-1.04088715e-03, -1.04385993e-03, -1.04140124e-03, ...,
#         -1.25638031e-03, -1.26659505e-03, -1.25629090e-03],
#        [-3.61315928e-05, -7.07991463e-05, -6.83628063e-05, ...,
#         -8.19303144e-05, -8.12821139e-05, -8.24444045e-05],
#        [-4.35076680e-05, -8.49925032e-05, -9.23909302e-05, ...,
#         -2.84235941e-04, -2.82939540e-04, -2.83945369e-04]])

# %%
data.shape
# Out:
# (10, 3250)

# %%
data[0]
data[0].shape
# Out:
# (3250,)

# %%
data[0]
# Out:
# array([-4.61228219e-05, -4.77097957e-05, -4.64357463e-05, ...,
#        -3.80314909e-05, -4.82015340e-05, -3.81656014e-05])

# %%
raw.info["ch_names"]
# Out:
# ['EEG 1',
#  'EEG 2',
#  'EEG 3',
#  'EEG 4',
#  'EEG 5',
#  'EEG 6',
#  'EEG 7',
#  'EEG 8',
#  'EEG 9',
#  'EEG 10',
#  'EEG 11',
#  'EEG 12',
#  'EEG 13',
#  'EEG 14',
#  'EEG 15',
#  'EEG 16',
#  'Accel X',
#  'Accel Y',
#  'Accel Z']

# %%
data, times = raw[:]

# %%
data.shape
# Out:
# (19, 3250)

# %%
data[19]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 data[19]
#
# IndexError: index 19 is out of bounds for axis 0 with size 19

# %%
data[18]
# Out:
# array([0.0009768, 0.0009768, 0.0009768, ..., 0.0009768, 0.0009768,
#        0.0009768])

# %%
data[0]
# Out:
# array([-4.61228219e-05, -4.77097957e-05, -4.64357463e-05, ...,
#        -3.80314909e-05, -4.82015340e-05, -3.81656014e-05])

# %%
raw.drop_channels(["Accel X", "Accel Y", "Accel Z"])
# Out:
# <RawEDF | OpenBCI-BDF-2024-01-27_16-54-38.bdf, 16 x 3250 (26.0 s), ~423 kB, data loaded>

# %%
data, times = raw[:]dddd
